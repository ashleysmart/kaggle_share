# %%
import numpy as np

# %matplotlib inline
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = 10, 10

# %%
dataDir = './data'
#img_id = "6010_0_0"
#img_id = "6120_2_4"
img_id = "6070_2_3"

# %%
#################################################################
###################### BAND data loader #########################
#################################################################

# %%
import libs.raw_loader

# %%
img = libs.raw_loader.img_3band(img_id)

# %%
print img.shape
# Out:
# (3350, 3338, 3)

# %%
# raw tiff... yea..
plt.imshow(img.astype(np.float))

# %%
import libs.img_argument

# %%
img2 = libs.img_argument.equalize_channels(img)

# %%
plt.imshow(img2)

# %%
img3 = libs.img_argument.stretch_n(img)

# %%
plt.imshow(img3)
