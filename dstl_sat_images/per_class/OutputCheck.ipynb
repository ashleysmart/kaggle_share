# %%
import numpy as np

# %matplotlib inline
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = 20, 20

# %%
#trees example...
dataDir = './data'
img_id="6010_4_2"
chan=5

# %%
mask = np.load("./predictions/mask_" + img_id + "_chan_" + str(chan) + ".npy").astype(np.float32)

# %%
print mask.shape
print mask.dtype
# Out:
# (3345, 3396, 1)
# float32

# %%
plt.imshow(mask[:,:,0])
plt.show()

# %%
plt.imshow(mask[:,:,0] > 0.1)
plt.show()
plt.imshow(mask[:,:,0] > 0.5)
plt.show()
